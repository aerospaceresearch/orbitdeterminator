# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.coordinates as coord
import astropy.units as u
from astropy import time as t

from poliastro.bodies import Earth
from poliastro.twobody import Orbit
import poliastro

import urllib.request
import json
from collections import OrderedDict

import emcee

# %% [markdown]
# # Loading a single File

# %%
# read file
with open('testing_data/00_jena_iss_test.json', 'r') as myfile:
    data=myfile.read()

# %%
obj = json.loads(data)

# %%
obj
# Out:
# {'__comment': None,
#  'meta_data': {'file_name': '00_jena_iss_test.json',
#   'gs_count': 1,
#   'sat_count': 1},
#  'ground_station': {'gs_id': 'JENA',
#   'lat': 50.9271,
#   'lon': 11.5892,
#   'alt': 143,
#   'monitored': 'ISS'},
#  'satellites': [{'sat_id': 25544,
#    'f_c': 630000000.0,
#    'data_stream': [{'time_unix': '1562810340.000',
#      'time_gnss': None,
#      'f_m': '629991146.55',
#      'gs_distance': '2317.41'},
#     {'time_unix': '1562810350.000',
#      'time_gnss': None,
#      'f_m': '629991438.73',
#      'gs_distance': '2275.97'},
#     {'time_unix': '1562810360.000',
#      'time_gnss': None,
#      'f_m': '629991748.03',
#      'gs_distance': '2235.96'},
#     {'time_unix': '1562810370.000',
#      'time_gnss': None,
#      'f_m': '629992075.01',
#      'gs_distance': '2197.46'},
#     {'time_unix': '1562810380.000',
#      'time_gnss': None,
#      'f_m': '629992420.17',
#      'gs_distance': '2160.56'},
#     {'time_unix': '1562810390.000',
#      'time_gnss': None,
#      'f_m': '629992783.93',
#      'gs_distance': '2125.35'},
#     {'time_unix': '1562810400.000',
#      'time_gnss': None,
#      'f_m': '629993166.57',
#      'gs_distance': '2091.91'},
#     {'time_unix': '1562810410.000',
#      'time_gnss': None,
#      'f_m': '629993568.25',
#      'gs_distance': '2060.34'},
#     {'time_unix': '1562810420.000',
#      'time_gnss': None,
#      'f_m': '629993988.94',
#      'gs_distance': '2030.73'},
#     {'time_unix': '1562810430.000',
#      'time_gnss': None,
#      'f_m': '629994428.45',
#      'gs_distance': '2003.17'},
#     {'time_unix': '1562810440.000',
#      'time_gnss': None,
#      'f_m': '629994886.37',
#      'gs_distance': '1977.74'},
#     {'time_unix': '1562810450.000',
#      'time_gnss': None,
#      'f_m': '629995362.05',
#      'gs_distance': '1954.53'},
#     {'time_unix': '1562810460.000',
#      'time_gnss': None,
#      'f_m': '629995854.60',
#      'gs_distance': '1933.62'},
#     {'time_unix': '1562810470.000',
#      'time_gnss': None,
#      'f_m': '629996362.88',
#      'gs_distance': '1915.10'},
#     {'time_unix': '1562810480.000',
#      'time_gnss': None,
#      'f_m': '629996885.48',
#      'gs_distance': '1899.03'},
#     {'time_unix': '1562810490.000',
#      'time_gnss': None,
#      'f_m': '629997420.76',
#      'gs_distance': '1885.48'},
#     {'time_unix': '1562810500.000',
#      'time_gnss': None,
#      'f_m': '629997966.82',
#      'gs_distance': '1874.50'},
#     {'time_unix': '1562810510.000',
#      'time_gnss': None,
#      'f_m': '629998521.57',
#      'gs_distance': '1866.14'},
#     {'time_unix': '1562810520.000',
#      'time_gnss': None,
#      'f_m': '629999082.72',
#      'gs_distance': '1860.44'},
#     {'time_unix': '1562810530.000',
#      'time_gnss': None,
#      'f_m': '629999647.86',
#      'gs_distance': '1857.42'},
#     {'time_unix': '1562810540.000',
#      'time_gnss': None,
#      'f_m': '630000214.50',
#      'gs_distance': '1857.09'},
#     {'time_unix': '1562810550.000',
#      'time_gnss': None,
#      'f_m': '630000780.11',
#      'gs_distance': '1859.46'},
#     {'time_unix': '1562810560.000',
#      'time_gnss': None,
#      'f_m': '630001342.17',
#      'gs_distance': '1864.51'},
#     {'time_unix': '1562810570.000',
#      'time_gnss': None,
#      'f_m': '630001898.25',
#      'gs_distance': '1872.22'},
#     {'time_unix': '1562810580.000',
#      'time_gnss': None,
#      'f_m': '630002446.04',
#      'gs_distance': '1882.56'},
#     {'time_unix': '1562810590.000',
#      'time_gnss': None,
#      'f_m': '630002983.41',
#      'gs_distance': '1895.48'},
#     {'time_unix': '1562810600.000',
#      'time_gnss': None,
#      'f_m': '630003508.42',
#      'gs_distance': '1910.94'},
#     {'time_unix': '1562810610.000',
#      'time_gnss': None,
#      'f_m': '630004019.36',
#      'gs_distance': '1928.85'},
#     {'time_unix': '1562810620.000',
#      'time_gnss': None,
#      'f_m': '630004514.79',
#      'gs_distance': '1949.16'},
#     {'time_unix': '1562810630.000',
#      'time_gnss': None,
#      'f_m': '630004993.51',
#      'gs_distance': '1971.79'},
#     {'time_unix': '1562810640.000',
#      'time_gnss': None,
#      'f_m': '630005454.58',
#      'gs_distance': '1996.66'},
#     {'time_unix': '1562810650.000',
#      'time_gnss': None,
#      'f_m': '630005897.31',
#      'gs_distance': '2023.68'},
#     {'time_unix': '1562810660.000',
#      'time_gnss': None,
#      'f_m': '630006321.24',
#      'gs_distance': '2052.76'},
#     {'time_unix': '1562810670.000',
#      'time_gnss': None,
#      'f_m': '630006726.13',
#      'gs_distance': '2083.81'},
#     {'time_unix': '1562810680.000',
#      'time_gnss': None,
#      'f_m': '630007111.94',
#      'gs_distance': '2116.74'},
#     {'time_unix': '1562810690.000',
#      'time_gnss': None,
#      'f_m': '630007478.78',
#      'gs_distance': '2151.46'},
#     {'time_unix': '1562810700.000',
#      'time_gnss': None,
#      'f_m': '630007826.92',
#      'gs_distance': '2187.89'},
#     {'time_unix': '1562810710.000',
#      'time_gnss': None,
#      'f_m': '630008156.74',
#      'gs_distance': '2225.93'},
#     {'time_unix': '1562810720.000',
#      'time_gnss': None,
#      'f_m': '630008468.74',
#      'gs_distance': '2265.49'},
#     {'time_unix': '1562810730.000',
#      'time_gnss': None,
#      'f_m': '630008763.46',
#      'gs_distance': '2306.50'},
#     {'time_unix': '1562810740.000',
#      'time_gnss': None,
#      'f_m': '630009041.54',
#      'gs_distance': '2348.87'},
#     {'time_unix': '1562810750.000',
#      'time_gnss': None,
#      'f_m': '630009303.63',
#      'gs_distance': '2392.52'},
#     {'time_unix': '1562810760.000',
#      'time_gnss': None,
#      'f_m': '630009550.41',
#      'gs_distance': '2437.39'},
#     {'time_unix': '1562810770.000',
#      'time_gnss': None,
#      'f_m': '630009782.59',
#      'gs_distance': '2483.39'},
#     {'time_unix': '1562810780.000',
#      'time_gnss': None,
#      'f_m': '630010000.87',
#      'gs_distance': '2530.47'},
#     {'time_unix': '1562810790.000',
#      'time_gnss': None,
#      'f_m': '630010205.94',
#      'gs_distance': '2578.55'},
#     {'time_unix': '1562810800.000',
#      'time_gnss': None,
#      'f_m': '630010398.49',
#      'gs_distance': '2627.58'},
#     {'time_unix': '1562810810.000',
#      'time_gnss': None,
#      'f_m': '630010579.18',
#      'gs_distance': '2677.50'},
#     {'time_unix': '1562810820.000',
#      'time_gnss': None,
#      'f_m': '630010748.67',
#      'gs_distance': '2728.25'},
#     {'time_unix': '1562810830.000',
#      'time_gnss': None,
#      'f_m': '630010907.58',
#      'gs_distance': '2779.78'},
#     {'time_unix': '1562810840.000',
#      'time_gnss': None,
#      'f_m': '630011056.49',
#      'gs_distance': '2832.04'},
#     {'time_unix': '1562810850.000',
#      'time_gnss': None,
#      'f_m': '630011195.98',
#      'gs_distance': '2884.99'},
#     {'time_unix': '1562810860.000',
#      'time_gnss': None,
#      'f_m': '630011326.58',
#      'gs_distance': '2938.58'},
#     {'time_unix': '1562810870.000',
#      'time_gnss': None,
#      'f_m': '630011448.81',
#      'gs_distance': '2992.77'}]}]}

# %%
print(obj.keys())
# Out:
# dict_keys(['__comment', 'meta_data', 'ground_station', 'satellites'])

# %%
obj['ground_station']
# Out:
# {'gs_id': 'JENA',
#  'lat': 50.9271,
#  'lon': 11.5892,
#  'alt': 143,
#  'monitored': 'ISS'}

# %%
GS = obj['ground_station']

# %%
obj['meta_data']
# Out:
# {'file_name': '00_jena_iss_test.json', 'gs_count': 1, 'sat_count': 1}

# %%
obj['satellites']
# Out:
# [{'sat_id': 25544,
#   'f_c': 630000000.0,
#   'data_stream': [{'time_unix': '1562810340.000',
#     'time_gnss': None,
#     'f_m': '629991146.55',
#     'gs_distance': '2317.41'},
#    {'time_unix': '1562810350.000',
#     'time_gnss': None,
#     'f_m': '629991438.73',
#     'gs_distance': '2275.97'},
#    {'time_unix': '1562810360.000',
#     'time_gnss': None,
#     'f_m': '629991748.03',
#     'gs_distance': '2235.96'},
#    {'time_unix': '1562810370.000',
#     'time_gnss': None,
#     'f_m': '629992075.01',
#     'gs_distance': '2197.46'},
#    {'time_unix': '1562810380.000',
#     'time_gnss': None,
#     'f_m': '629992420.17',
#     'gs_distance': '2160.56'},
#    {'time_unix': '1562810390.000',
#     'time_gnss': None,
#     'f_m': '629992783.93',
#     'gs_distance': '2125.35'},
#    {'time_unix': '1562810400.000',
#     'time_gnss': None,
#     'f_m': '629993166.57',
#     'gs_distance': '2091.91'},
#    {'time_unix': '1562810410.000',
#     'time_gnss': None,
#     'f_m': '629993568.25',
#     'gs_distance': '2060.34'},
#    {'time_unix': '1562810420.000',
#     'time_gnss': None,
#     'f_m': '629993988.94',
#     'gs_distance': '2030.73'},
#    {'time_unix': '1562810430.000',
#     'time_gnss': None,
#     'f_m': '629994428.45',
#     'gs_distance': '2003.17'},
#    {'time_unix': '1562810440.000',
#     'time_gnss': None,
#     'f_m': '629994886.37',
#     'gs_distance': '1977.74'},
#    {'time_unix': '1562810450.000',
#     'time_gnss': None,
#     'f_m': '629995362.05',
#     'gs_distance': '1954.53'},
#    {'time_unix': '1562810460.000',
#     'time_gnss': None,
#     'f_m': '629995854.60',
#     'gs_distance': '1933.62'},
#    {'time_unix': '1562810470.000',
#     'time_gnss': None,
#     'f_m': '629996362.88',
#     'gs_distance': '1915.10'},
#    {'time_unix': '1562810480.000',
#     'time_gnss': None,
#     'f_m': '629996885.48',
#     'gs_distance': '1899.03'},
#    {'time_unix': '1562810490.000',
#     'time_gnss': None,
#     'f_m': '629997420.76',
#     'gs_distance': '1885.48'},
#    {'time_unix': '1562810500.000',
#     'time_gnss': None,
#     'f_m': '629997966.82',
#     'gs_distance': '1874.50'},
#    {'time_unix': '1562810510.000',
#     'time_gnss': None,
#     'f_m': '629998521.57',
#     'gs_distance': '1866.14'},
#    {'time_unix': '1562810520.000',
#     'time_gnss': None,
#     'f_m': '629999082.72',
#     'gs_distance': '1860.44'},
#    {'time_unix': '1562810530.000',
#     'time_gnss': None,
#     'f_m': '629999647.86',
#     'gs_distance': '1857.42'},
#    {'time_unix': '1562810540.000',
#     'time_gnss': None,
#     'f_m': '630000214.50',
#     'gs_distance': '1857.09'},
#    {'time_unix': '1562810550.000',
#     'time_gnss': None,
#     'f_m': '630000780.11',
#     'gs_distance': '1859.46'},
#    {'time_unix': '1562810560.000',
#     'time_gnss': None,
#     'f_m': '630001342.17',
#     'gs_distance': '1864.51'},
#    {'time_unix': '1562810570.000',
#     'time_gnss': None,
#     'f_m': '630001898.25',
#     'gs_distance': '1872.22'},
#    {'time_unix': '1562810580.000',
#     'time_gnss': None,
#     'f_m': '630002446.04',
#     'gs_distance': '1882.56'},
#    {'time_unix': '1562810590.000',
#     'time_gnss': None,
#     'f_m': '630002983.41',
#     'gs_distance': '1895.48'},
#    {'time_unix': '1562810600.000',
#     'time_gnss': None,
#     'f_m': '630003508.42',
#     'gs_distance': '1910.94'},
#    {'time_unix': '1562810610.000',
#     'time_gnss': None,
#     'f_m': '630004019.36',
#     'gs_distance': '1928.85'},
#    {'time_unix': '1562810620.000',
#     'time_gnss': None,
#     'f_m': '630004514.79',
#     'gs_distance': '1949.16'},
#    {'time_unix': '1562810630.000',
#     'time_gnss': None,
#     'f_m': '630004993.51',
#     'gs_distance': '1971.79'},
#    {'time_unix': '1562810640.000',
#     'time_gnss': None,
#     'f_m': '630005454.58',
#     'gs_distance': '1996.66'},
#    {'time_unix': '1562810650.000',
#     'time_gnss': None,
#     'f_m': '630005897.31',
#     'gs_distance': '2023.68'},
#    {'time_unix': '1562810660.000',
#     'time_gnss': None,
#     'f_m': '630006321.24',
#     'gs_distance': '2052.76'},
#    {'time_unix': '1562810670.000',
#     'time_gnss': None,
#     'f_m': '630006726.13',
#     'gs_distance': '2083.81'},
#    {'time_unix': '1562810680.000',
#     'time_gnss': None,
#     'f_m': '630007111.94',
#     'gs_distance': '2116.74'},
#    {'time_unix': '1562810690.000',
#     'time_gnss': None,
#     'f_m': '630007478.78',
#     'gs_distance': '2151.46'},
#    {'time_unix': '1562810700.000',
#     'time_gnss': None,
#     'f_m': '630007826.92',
#     'gs_distance': '2187.89'},
#    {'time_unix': '1562810710.000',
#     'time_gnss': None,
#     'f_m': '630008156.74',
#     'gs_distance': '2225.93'},
#    {'time_unix': '1562810720.000',
#     'time_gnss': None,
#     'f_m': '630008468.74',
#     'gs_distance': '2265.49'},
#    {'time_unix': '1562810730.000',
#     'time_gnss': None,
#     'f_m': '630008763.46',
#     'gs_distance': '2306.50'},
#    {'time_unix': '1562810740.000',
#     'time_gnss': None,
#     'f_m': '630009041.54',
#     'gs_distance': '2348.87'},
#    {'time_unix': '1562810750.000',
#     'time_gnss': None,
#     'f_m': '630009303.63',
#     'gs_distance': '2392.52'},
#    {'time_unix': '1562810760.000',
#     'time_gnss': None,
#     'f_m': '630009550.41',
#     'gs_distance': '2437.39'},
#    {'time_unix': '1562810770.000',
#     'time_gnss': None,
#     'f_m': '630009782.59',
#     'gs_distance': '2483.39'},
#    {'time_unix': '1562810780.000',
#     'time_gnss': None,
#     'f_m': '630010000.87',
#     'gs_distance': '2530.47'},
#    {'time_unix': '1562810790.000',
#     'time_gnss': None,
#     'f_m': '630010205.94',
#     'gs_distance': '2578.55'},
#    {'time_unix': '1562810800.000',
#     'time_gnss': None,
#     'f_m': '630010398.49',
#     'gs_distance': '2627.58'},
#    {'time_unix': '1562810810.000',
#     'time_gnss': None,
#     'f_m': '630010579.18',
#     'gs_distance': '2677.50'},
#    {'time_unix': '1562810820.000',
#     'time_gnss': None,
#     'f_m': '630010748.67',
#     'gs_distance': '2728.25'},
#    {'time_unix': '1562810830.000',
#     'time_gnss': None,
#     'f_m': '630010907.58',
#     'gs_distance': '2779.78'},
#    {'time_unix': '1562810840.000',
#     'time_gnss': None,
#     'f_m': '630011056.49',
#     'gs_distance': '2832.04'},
#    {'time_unix': '1562810850.000',
#     'time_gnss': None,
#     'f_m': '630011195.98',
#     'gs_distance': '2884.99'},
#    {'time_unix': '1562810860.000',
#     'time_gnss': None,
#     'f_m': '630011326.58',
#     'gs_distance': '2938.58'},
#    {'time_unix': '1562810870.000',
#     'time_gnss': None,
#     'f_m': '630011448.81',
#     'gs_distance': '2992.77'}]}]

# %%
obj['satellites'][0]['sat_id']
# Out:
# 25544

# %%
obj['satellites'][0].keys()
# Out:
# dict_keys(['sat_id', 'f_c', 'data_stream'])

# %%
obj['satellites'][0]['f_c']
# Out:
# 630000000.0

# %%
obj['satellites'][0]['data_stream']
# Out:
# [{'time_unix': '1562810340.000',
#   'time_gnss': None,
#   'f_m': '629991146.55',
#   'gs_distance': '2317.41'},
#  {'time_unix': '1562810350.000',
#   'time_gnss': None,
#   'f_m': '629991438.73',
#   'gs_distance': '2275.97'},
#  {'time_unix': '1562810360.000',
#   'time_gnss': None,
#   'f_m': '629991748.03',
#   'gs_distance': '2235.96'},
#  {'time_unix': '1562810370.000',
#   'time_gnss': None,
#   'f_m': '629992075.01',
#   'gs_distance': '2197.46'},
#  {'time_unix': '1562810380.000',
#   'time_gnss': None,
#   'f_m': '629992420.17',
#   'gs_distance': '2160.56'},
#  {'time_unix': '1562810390.000',
#   'time_gnss': None,
#   'f_m': '629992783.93',
#   'gs_distance': '2125.35'},
#  {'time_unix': '1562810400.000',
#   'time_gnss': None,
#   'f_m': '629993166.57',
#   'gs_distance': '2091.91'},
#  {'time_unix': '1562810410.000',
#   'time_gnss': None,
#   'f_m': '629993568.25',
#   'gs_distance': '2060.34'},
#  {'time_unix': '1562810420.000',
#   'time_gnss': None,
#   'f_m': '629993988.94',
#   'gs_distance': '2030.73'},
#  {'time_unix': '1562810430.000',
#   'time_gnss': None,
#   'f_m': '629994428.45',
#   'gs_distance': '2003.17'},
#  {'time_unix': '1562810440.000',
#   'time_gnss': None,
#   'f_m': '629994886.37',
#   'gs_distance': '1977.74'},
#  {'time_unix': '1562810450.000',
#   'time_gnss': None,
#   'f_m': '629995362.05',
#   'gs_distance': '1954.53'},
#  {'time_unix': '1562810460.000',
#   'time_gnss': None,
#   'f_m': '629995854.60',
#   'gs_distance': '1933.62'},
#  {'time_unix': '1562810470.000',
#   'time_gnss': None,
#   'f_m': '629996362.88',
#   'gs_distance': '1915.10'},
#  {'time_unix': '1562810480.000',
#   'time_gnss': None,
#   'f_m': '629996885.48',
#   'gs_distance': '1899.03'},
#  {'time_unix': '1562810490.000',
#   'time_gnss': None,
#   'f_m': '629997420.76',
#   'gs_distance': '1885.48'},
#  {'time_unix': '1562810500.000',
#   'time_gnss': None,
#   'f_m': '629997966.82',
#   'gs_distance': '1874.50'},
#  {'time_unix': '1562810510.000',
#   'time_gnss': None,
#   'f_m': '629998521.57',
#   'gs_distance': '1866.14'},
#  {'time_unix': '1562810520.000',
#   'time_gnss': None,
#   'f_m': '629999082.72',
#   'gs_distance': '1860.44'},
#  {'time_unix': '1562810530.000',
#   'time_gnss': None,
#   'f_m': '629999647.86',
#   'gs_distance': '1857.42'},
#  {'time_unix': '1562810540.000',
#   'time_gnss': None,
#   'f_m': '630000214.50',
#   'gs_distance': '1857.09'},
#  {'time_unix': '1562810550.000',
#   'time_gnss': None,
#   'f_m': '630000780.11',
#   'gs_distance': '1859.46'},
#  {'time_unix': '1562810560.000',
#   'time_gnss': None,
#   'f_m': '630001342.17',
#   'gs_distance': '1864.51'},
#  {'time_unix': '1562810570.000',
#   'time_gnss': None,
#   'f_m': '630001898.25',
#   'gs_distance': '1872.22'},
#  {'time_unix': '1562810580.000',
#   'time_gnss': None,
#   'f_m': '630002446.04',
#   'gs_distance': '1882.56'},
#  {'time_unix': '1562810590.000',
#   'time_gnss': None,
#   'f_m': '630002983.41',
#   'gs_distance': '1895.48'},
#  {'time_unix': '1562810600.000',
#   'time_gnss': None,
#   'f_m': '630003508.42',
#   'gs_distance': '1910.94'},
#  {'time_unix': '1562810610.000',
#   'time_gnss': None,
#   'f_m': '630004019.36',
#   'gs_distance': '1928.85'},
#  {'time_unix': '1562810620.000',
#   'time_gnss': None,
#   'f_m': '630004514.79',
#   'gs_distance': '1949.16'},
#  {'time_unix': '1562810630.000',
#   'time_gnss': None,
#   'f_m': '630004993.51',
#   'gs_distance': '1971.79'},
#  {'time_unix': '1562810640.000',
#   'time_gnss': None,
#   'f_m': '630005454.58',
#   'gs_distance': '1996.66'},
#  {'time_unix': '1562810650.000',
#   'time_gnss': None,
#   'f_m': '630005897.31',
#   'gs_distance': '2023.68'},
#  {'time_unix': '1562810660.000',
#   'time_gnss': None,
#   'f_m': '630006321.24',
#   'gs_distance': '2052.76'},
#  {'time_unix': '1562810670.000',
#   'time_gnss': None,
#   'f_m': '630006726.13',
#   'gs_distance': '2083.81'},
#  {'time_unix': '1562810680.000',
#   'time_gnss': None,
#   'f_m': '630007111.94',
#   'gs_distance': '2116.74'},
#  {'time_unix': '1562810690.000',
#   'time_gnss': None,
#   'f_m': '630007478.78',
#   'gs_distance': '2151.46'},
#  {'time_unix': '1562810700.000',
#   'time_gnss': None,
#   'f_m': '630007826.92',
#   'gs_distance': '2187.89'},
#  {'time_unix': '1562810710.000',
#   'time_gnss': None,
#   'f_m': '630008156.74',
#   'gs_distance': '2225.93'},
#  {'time_unix': '1562810720.000',
#   'time_gnss': None,
#   'f_m': '630008468.74',
#   'gs_distance': '2265.49'},
#  {'time_unix': '1562810730.000',
#   'time_gnss': None,
#   'f_m': '630008763.46',
#   'gs_distance': '2306.50'},
#  {'time_unix': '1562810740.000',
#   'time_gnss': None,
#   'f_m': '630009041.54',
#   'gs_distance': '2348.87'},
#  {'time_unix': '1562810750.000',
#   'time_gnss': None,
#   'f_m': '630009303.63',
#   'gs_distance': '2392.52'},
#  {'time_unix': '1562810760.000',
#   'time_gnss': None,
#   'f_m': '630009550.41',
#   'gs_distance': '2437.39'},
#  {'time_unix': '1562810770.000',
#   'time_gnss': None,
#   'f_m': '630009782.59',
#   'gs_distance': '2483.39'},
#  {'time_unix': '1562810780.000',
#   'time_gnss': None,
#   'f_m': '630010000.87',
#   'gs_distance': '2530.47'},
#  {'time_unix': '1562810790.000',
#   'time_gnss': None,
#   'f_m': '630010205.94',
#   'gs_distance': '2578.55'},
#  {'time_unix': '1562810800.000',
#   'time_gnss': None,
#   'f_m': '630010398.49',
#   'gs_distance': '2627.58'},
#  {'time_unix': '1562810810.000',
#   'time_gnss': None,
#   'f_m': '630010579.18',
#   'gs_distance': '2677.50'},
#  {'time_unix': '1562810820.000',
#   'time_gnss': None,
#   'f_m': '630010748.67',
#   'gs_distance': '2728.25'},
#  {'time_unix': '1562810830.000',
#   'time_gnss': None,
#   'f_m': '630010907.58',
#   'gs_distance': '2779.78'},
#  {'time_unix': '1562810840.000',
#   'time_gnss': None,
#   'f_m': '630011056.49',
#   'gs_distance': '2832.04'},
#  {'time_unix': '1562810850.000',
#   'time_gnss': None,
#   'f_m': '630011195.98',
#   'gs_distance': '2884.99'},
#  {'time_unix': '1562810860.000',
#   'time_gnss': None,
#   'f_m': '630011326.58',
#   'gs_distance': '2938.58'},
#  {'time_unix': '1562810870.000',
#   'time_gnss': None,
#   'f_m': '630011448.81',
#   'gs_distance': '2992.77'}]

# %%
data = obj['satellites'][0]['data_stream']

# %%
for dat in data:
    print(dat['time_unix'], dat['f_m'])
# Out:
# 1562810340.000 629991146.55
# 1562810350.000 629991438.73
# 1562810360.000 629991748.03
# 1562810370.000 629992075.01
# 1562810380.000 629992420.17
# 1562810390.000 629992783.93
# 1562810400.000 629993166.57
# 1562810410.000 629993568.25
# 1562810420.000 629993988.94
# 1562810430.000 629994428.45
# 1562810440.000 629994886.37
# 1562810450.000 629995362.05
# 1562810460.000 629995854.60
# 1562810470.000 629996362.88
# 1562810480.000 629996885.48
# 1562810490.000 629997420.76
# 1562810500.000 629997966.82
# 1562810510.000 629998521.57
# 1562810520.000 629999082.72
# 1562810530.000 629999647.86
# 1562810540.000 630000214.50
# 1562810550.000 630000780.11
# 1562810560.000 630001342.17
# 1562810570.000 630001898.25
# 1562810580.000 630002446.04
# 1562810590.000 630002983.41
# 1562810600.000 630003508.42
# 1562810610.000 630004019.36
# 1562810620.000 630004514.79
# 1562810630.000 630004993.51
# 1562810640.000 630005454.58
# 1562810650.000 630005897.31
# 1562810660.000 630006321.24
# 1562810670.000 630006726.13
# 1562810680.000 630007111.94
# 1562810690.000 630007478.78
# 1562810700.000 630007826.92
# 1562810710.000 630008156.74
# 1562810720.000 630008468.74
# 1562810730.000 630008763.46
# 1562810740.000 630009041.54
# 1562810750.000 630009303.63
# 1562810760.000 630009550.41
# 1562810770.000 630009782.59
# 1562810780.000 630010000.87
# 1562810790.000 630010205.94
# 1562810800.000 630010398.49
# 1562810810.000 630010579.18
# 1562810820.000 630010748.67
# 1562810830.000 630010907.58
# 1562810840.000 630011056.49
# 1562810850.000 630011195.98
# 1562810860.000 630011326.58
# 1562810870.000 630011448.81

# %%
timelist = []

for dat in data:
    T = dat['time_unix']
    T = float(T)
    timelist.append( t.Time(T, format="unix", scale="utc"))

# %%
timelist
# Out:
# [<Time object: scale='utc' format='unix' value=1562810340.0>,
#  <Time object: scale='utc' format='unix' value=1562810350.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810360.0>,
#  <Time object: scale='utc' format='unix' value=1562810370.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810380.0>,
#  <Time object: scale='utc' format='unix' value=1562810390.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810400.0>,
#  <Time object: scale='utc' format='unix' value=1562810410.0>,
#  <Time object: scale='utc' format='unix' value=1562810420.0>,
#  <Time object: scale='utc' format='unix' value=1562810430.0>,
#  <Time object: scale='utc' format='unix' value=1562810440.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810450.0>,
#  <Time object: scale='utc' format='unix' value=1562810460.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810470.0>,
#  <Time object: scale='utc' format='unix' value=1562810480.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810490.0>,
#  <Time object: scale='utc' format='unix' value=1562810500.0>,
#  <Time object: scale='utc' format='unix' value=1562810510.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810520.0>,
#  <Time object: scale='utc' format='unix' value=1562810530.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810540.0>,
#  <Time object: scale='utc' format='unix' value=1562810550.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810560.0>,
#  <Time object: scale='utc' format='unix' value=1562810570.0>,
#  <Time object: scale='utc' format='unix' value=1562810580.0>,
#  <Time object: scale='utc' format='unix' value=1562810590.0>,
#  <Time object: scale='utc' format='unix' value=1562810600.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810610.0>,
#  <Time object: scale='utc' format='unix' value=1562810620.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810630.0>,
#  <Time object: scale='utc' format='unix' value=1562810640.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810650.0>,
#  <Time object: scale='utc' format='unix' value=1562810660.0>,
#  <Time object: scale='utc' format='unix' value=1562810670.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810680.0>,
#  <Time object: scale='utc' format='unix' value=1562810690.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810700.0>,
#  <Time object: scale='utc' format='unix' value=1562810710.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810720.0>,
#  <Time object: scale='utc' format='unix' value=1562810730.0>,
#  <Time object: scale='utc' format='unix' value=1562810740.0>,
#  <Time object: scale='utc' format='unix' value=1562810750.0>,
#  <Time object: scale='utc' format='unix' value=1562810760.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810770.0>,
#  <Time object: scale='utc' format='unix' value=1562810780.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810790.0>,
#  <Time object: scale='utc' format='unix' value=1562810800.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810810.0>,
#  <Time object: scale='utc' format='unix' value=1562810820.0>,
#  <Time object: scale='utc' format='unix' value=1562810830.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810840.0>,
#  <Time object: scale='utc' format='unix' value=1562810850.0000002>,
#  <Time object: scale='utc' format='unix' value=1562810860.0>,
#  <Time object: scale='utc' format='unix' value=1562810870.0000002>]

# %%
GS
# Out:
# {'gs_id': 'JENA',
#  'lat': 50.9271,
#  'lon': 11.5892,
#  'alt': 143,
#  'monitored': 'ISS'}

# %%
gs = coord.EarthLocation( GS["lon"], GS["lat"], GS["alt"])

# %%
gs
# Out:
# <EarthLocation (3946293.3013581, 809282.50717543, 4928547.87338264) m>

# %%
gs.to_geodetic()
# Out:
# GeodeticLocation(lon=<Longitude 11.5892 deg>, lat=<Latitude 50.9271 deg>, height=<Quantity 143. m>)

# %%
GS_loc = []

for tau in timelist:
    GS_loc.append( gs.get_gcrs_posvel(obstime = tau ) )

# %% [markdown]
# ### Now we have the Ground Station location in XYZ in the Geocentric Inertial System.
#
# Regading, this is the System where Satellite coordinates are measured.

# %%
GS_loc
# Out:
# [(<CartesianRepresentation (x, y, z) in m
#       (3490465.92481309, -2027129.61147224, 4922006.3289872)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (147.81360806, 253.85855918, -0.27098031)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3491943.13465408, -2024590.48676804, 4922003.62070328)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (147.62831285, 253.96633589, -0.27066427)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3493418.49247404, -2022050.28547153, 4922000.91592309)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (147.44329233, 254.07394477, -0.27031771)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3494891.99757907, -2019509.00898642, 4921998.21460857)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (147.25782938, 254.18137056, -0.26993299)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3496363.64914558, -2016966.65871642, 4921995.51677508)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (147.0725648, 254.28870481, -0.2696093)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3497833.44652545, -2014423.23594316, 4921992.82243794)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (146.88690355, 254.39581018, -0.26927796)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3499301.38868909, -2011878.74208563, 4921990.13155149)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (146.70147121, 254.50293082, -0.26890085)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3500767.47504943, -2009333.17848648, 4921987.44416156)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (146.51568796, 254.60973103, -0.2685695)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3502231.70472182, -2006786.54641212, 4921984.76026062)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (146.33020991, 254.71657704, -0.26821527)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3503694.07705051, -2004238.84726623, 4921982.07984874)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (146.14428941, 254.82320942, -0.26786101)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3505154.59108986, -2001690.08251356, 4921979.4029184)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (145.95851389, 254.92976553, -0.26752201)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3506613.24626802, -1999140.25329842, 4921976.72948492)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (145.77254006, 255.03606225, -0.26717537)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3508070.04162408, -1996589.36116185, 4921974.05954839)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (145.58665781, 255.1423132, -0.2668211)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3509524.97647175, -1994037.40738549, 4921971.39307838)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (145.40034073, 255.24835053, -0.26645917)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3510978.05007139, -1991484.39331199, 4921968.73012838)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (145.21416864, 255.35431158, -0.26612776)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3512429.26148495, -1988930.32032981, 4921966.07066032)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (145.02810339, 255.46027265, -0.26577348)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3513878.61017874, -1986375.18978162, 4921963.41468955)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (144.84174065, 255.5659438, -0.26542679)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3515326.09516132, -1983819.00307112, 4921960.76220853)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (144.6553169, 255.67143186, -0.26505721)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3516771.71583036, -1981261.76149521, 4921958.11323258)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (144.46882453, 255.77691994, -0.26470289)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3518215.47127833, -1978703.46636603, 4921955.4677618)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (144.28217962, 255.8821181, -0.26438669)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3519657.36089526, -1976144.1191941, 4921952.82578101)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (144.09557288, 255.98723998, -0.2640476)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3521097.38366682, -1973583.72124578, 4921950.1873132)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (143.908867, 256.09227033, -0.26367799)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3522535.53924242, -1971022.27380272, 4921947.55235841)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (143.72212301, 256.19710232, -0.26332363)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3523971.82634072, -1968459.77845171, 4921944.92089388)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (143.53536379, 256.3019038, -0.26296164)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3525406.24461875, -1965896.23633706, 4921942.29293493)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (143.34838337, 256.40650693, -0.26259963)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3526838.79311561, -1963331.64893877, 4921939.66851217)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (143.1614335, 256.51094222, -0.26225288)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3528269.4711145, -1960766.01758422, 4921937.04756464)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (142.9742853, 256.61530123, -0.26191374)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3529698.27781471, -1958199.34363136, 4921934.43014583)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (142.78702271, 256.71947714, -0.26155934)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3531125.21257575, -1955631.62846861, 4921931.81624056)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (142.59985932, 256.82348522, -0.26122019)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3532550.27442907, -1953062.87351494, 4921929.2058413)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (142.41248999, 256.92744753, -0.26084288)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3533973.46285624, -1950493.07999093, 4921926.598971)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (142.22516646, 257.03121149, -0.26051134)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3535394.7768887, -1947922.24934605, 4921923.99560688)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (142.03763698, 257.13492968, -0.26016454)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3536814.21593937, -1945350.38296875, 4921921.39576425)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (141.85008465, 257.23840375, -0.25981772)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3538231.7791465, -1942777.48220169, 4921918.79945085)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (141.66251711, 257.34175577, -0.25945564)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3539647.46578567, -1940203.54838752, 4921916.20664386)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (141.47485804, 257.44498571, -0.25910118)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3541061.27513247, -1937628.58292993, 4921913.61735863)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (141.28693199, 257.54803256, -0.25875433)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3542473.2064167, -1935052.58721737, 4921911.03161049)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (141.09912041, 257.65095736, -0.25841512)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3543883.25890633, -1932475.56259249, 4921908.44938427)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (140.91126309, 257.75389743, -0.25804538)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3545291.43178536, -1929897.51038268, 4921905.87068768)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (140.72316167, 257.8565018, -0.25769088)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3546697.72440569, -1927318.43200691, 4921903.29550555)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (140.53525102, 257.95912147, -0.25732113)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3548102.1359132, -1924738.3288536, 4921900.72385321)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (140.34707338, 258.0615275, -0.25699714)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3549504.66558347, -1922157.2022654, 4921898.15576128)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (140.15891103, 258.16382675, -0.25662736)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3550905.31274548, -1919575.05360024, 4921895.59116878)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (139.97054273, 258.26595816, -0.25628046)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3552304.07652986, -1916991.88430757, 4921893.03011396)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (139.7823652, 258.36799803, -0.25591831)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3553700.95630375, -1914407.69566902, 4921890.47261978)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (139.59376048, 258.46974799, -0.25557138)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3555095.95130458, -1911822.48908828, 4921887.91864055)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (139.40533125, 258.57151323, -0.2552321)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3556489.0607774, -1909236.26592325, 4921885.36820687)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (139.21677998, 258.67318692, -0.25487754)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3557880.28401307, -1906649.02765392, 4921882.82129592)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (139.02793124, 258.77447916, -0.25451533)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3559269.62021849, -1904060.77551613, 4921880.27794595)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (138.83921221, 258.87581718, -0.25415313)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3560657.06869214, -1901471.51091356, 4921877.73811888)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (138.6505161, 258.97704841, -0.25378329)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3562042.62862568, -1898881.23534146, 4921875.20184533)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (138.4616827, 259.07806602, -0.25345922)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3563426.29934809, -1896289.95003567, 4921872.66911772)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (138.27256706, 259.17894631, -0.25310461)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3564808.08013496, -1893697.65644563, 4921870.13994379)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (138.0836193, 259.27976559, -0.25274238)>),
#  (<CartesianRepresentation (x, y, z) in m
#       (3566187.97021607, -1891104.35591401, 4921867.61430071)>,
#   <CartesianRepresentation (x, y, z) in m / s
#       (137.89448084, 259.38040177, -0.25240302)>)]

# %% [markdown]
# ### Now, calculate Doppler Shift 'z' from F_measured and F_c
